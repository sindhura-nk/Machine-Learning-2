# %% [markdown]
# In this end-to-end data analytics project, I have used cricket T20 world cup (2022) data to build insights on a best 11 players team that we can assemble from the earth that can go and play with aliens. We used bright data web scraping to collect data from espncricinfo website then we performed some data transformation and cleaning in pandas, followed by building dashboards in power bi.

# %% [markdown]
# ## Webscraping: Lets scrap the below website and gather the data
# https://www.espncricinfo.com/records/season/team-match-results/2022to23-2022to23?trophy=89

# %%
pip install html-table-parser-python3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Library for opening url and creating 
# requests
import urllib.request

# pretty-print python data structures
from pprint import pprint

# for parsing all the tables present 
# on the website
from html_table_parser.parser import HTMLTableParser

# for converting the parsed data in a
# pandas dataframe
import pandas as pd
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17220\1521808924.py:14: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Opens a website and read its
# binary contents (HTTP Response Body)
def url_get_contents(url):

    # Opens a website and read its
    # binary contents (HTTP Response Body)

    #making request to the website
    req = urllib.request.Request(url=url)
    f = urllib.request.urlopen(req)

    #reading contents of the website
    return f.read()

# %%
# defining the html contents of a URL.
xhtml = url_get_contents('https://www.espncricinfo.com/records/season/team-match-results/2022to23-2022to23?trophy=89').decode('utf-8')

# Defining the HTMLTableParser object
p = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p.feed(xhtml)

# Now finally obtaining the data of
# the table required
#pprint(p.tables[0][0])
#pprint(p.tables[0][1:])

# %%
col_name = p.tables[0][0]
col_name
# Out:
# ['Team 1', 'Team 2', 'Winner', 'Margin', 'Ground', 'Match Date', 'Scorecard']

# %%
# converting the parsed data to
# dataframe
print("\n\nPANDAS DATAFRAME\n")
df = pd.DataFrame(p.tables[0][1:],columns=col_name)
df.head()
# Out:
# PANDAS DATAFRAME
#         Team 1    Team 2    Winner      Margin     Ground    Match Date  \
# 0      England  Pakistan   England   5 wickets  Melbourne  Nov 13, 2022
# 1      England     India   England  10 wickets   Adelaide  Nov 10, 2022
# 2  New Zealand  Pakistan  Pakistan   7 wickets     Sydney   Nov 9, 2022
# 3        India  Zimbabwe     India     71 runs  Melbourne   Nov 6, 2022
# 4   Bangladesh  Pakistan  Pakistan   5 wickets   Adelaide   Nov 6, 2022
#
#      Scorecard
# 0  T20I # 1879
# 1  T20I # 1878
# 2  T20I # 1877
# 3  T20I # 1873
# 4  T20I # 1872

# %%
df.shape
# Out:
# (42, 7)

# %%
# df.to_csv('MatchResults.csv',index=False)

# %%
# defining the html contents of a URL.
xhtml2 = url_get_contents('https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-pakistan-final-1298179/full-scorecard').decode('utf-8')

# Defining the HTMLTableParser object
p1 = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p1.feed(xhtml2)

# Now finally obtaining the data of
# the table required
#pprint(p1.tables)
#pprint(p1.tables[0][0])
#pprint(p1.tables[0][1:19])

# %%
col_name1 = p1.tables[0][0]
col_name1
# Out:
# ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR']

# %%
# converting the parsed data to
# dataframe
print("\n\nPANDAS DATAFRAME\n")
df1 = pd.DataFrame(p1.tables[0][1:19],columns=col_name1)
df1.head()
# Out:
# PANDAS DATAFRAME
#               BATTING                        R     B     M    4s    6s      SR
# 0  Mohammad Rizwan  †           b Curran    15    14    24     0     1  107.14
# 1                                   None  None  None  None  None  None    None
# 2     Babar Azam  (c)         c b Rashid    32    28    58     2     0  114.28
# 3                                   None  None  None  None  None  None    None
# 4      Mohammad Haris  c Stokes b Rashid     8    12    15     1     0   66.66

# %%
#df1.to_csv('BattingResults.csv')

# %%
col_name2= p1.tables[1][0]

# %%
p1.tables[1][1]
# Out:
# ['Ben Stokes', '4', '0', '32', '1', '8.00', '6', '1', '0', '2', '1']

# %%
# converting the parsed data to
# dataframe
print("\n\nPANDAS DATAFRAME\n")
dfb = pd.DataFrame(p1.tables[1][1:],columns=col_name2)
dfb.head()
# Out:
# PANDAS DATAFRAME
#                                              BOWLING     O     M     R     W  \
# 0                                         Ben Stokes     4     0    32     1
# 1  12.2 to  Iftikhar Ahmed ,  nibbles outside off...  None  None  None  None
# 2                                       Chris Woakes     3     0    26     0
# 3                                         Sam Curran     4     0    12     3
# 4  4.2 to  Mohammad Rizwan ,  bowled him, Rizwan'...  None  None  None  None
#
#    ECON    0s    4s    6s    WD    NB
# 0  8.00     6     1     0     2     1
# 1  None  None  None  None  None  None
# 2  8.66     7     2     1     2     0
# 3  3.00    15     0     0     0     0
# 4  None  None  None  None  None  None

# %%
col_name1 = p1.tables[0][0] # batting column header
col_name2 = p1.tables[1][0] # bowling column header

# %%
# converting the parsed data to 2 different dataframes : batting and bowling
dfbat = pd.DataFrame(p1.tables[0][1:],columns=col_name1)
dfball = pd.DataFrame(p1.tables[1][1:],columns=col_name2)

# %%
dfbat.head()
# Out:
#               BATTING                        R     B     M    4s    6s      SR
# 0  Mohammad Rizwan  †           b Curran    15    14    24     0     1  107.14
# 1                                   None  None  None  None  None  None    None
# 2     Babar Azam  (c)         c b Rashid    32    28    58     2     0  114.28
# 3                                   None  None  None  None  None  None    None
# 4      Mohammad Haris  c Stokes b Rashid     8    12    15     1     0   66.66

# %%
dfball.head()
# Out:
#                                              BOWLING     O     M     R     W  \
# 0                                         Ben Stokes     4     0    32     1
# 1  12.2 to  Iftikhar Ahmed ,  nibbles outside off...  None  None  None  None
# 2                                       Chris Woakes     3     0    26     0
# 3                                         Sam Curran     4     0    12     3
# 4  4.2 to  Mohammad Rizwan ,  bowled him, Rizwan'...  None  None  None  None
#
#    ECON    0s    4s    6s    WD    NB
# 0  8.00     6     1     0     2     1
# 1  None  None  None  None  None  None
# 2  8.66     7     2     1     2     0
# 3  3.00    15     0     0     0     0
# 4  None  None  None  None  None  None

# %%
import requests
response = requests.get("https://www.espncricinfo.com/records/season/team-match-results/2022to23-2022to23?trophy=89")
response
# Out:
# <Response [200]>

# %%
data = response.content
data
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><link rel="preconnect" href="https://img1.hscicdn.com" crossorigin="anonymous"/><link rel="preconnect" href="https://dcf.espn.com" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v2.24/fonts/icomoon.woff?gencn3" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" as="font" type="font/woff" crossorigin="anonymous"/><script type="text/javascript">\n          /*! js-cookie v3.0.5 | MIT */\n          !function(e,
# ...

# %%
from bs4 import BeautifulSoup
bs = BeautifulSoup(data)

# %%
scorecards = bs.find_all('a',class_="ds-inline-flex ds-items-start ds-leading-none")
scorecards[:2]
# Out:
# [<a class="ds-inline-flex ds-items-start ds-leading-none" href="/cricket-grounds/melbourne-cricket-ground-56441" title="Melbourne"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">Melbourne</span></a>,
#  <a class="ds-inline-flex ds-items-start ds-leading-none" href="/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-pakistan-final-1298179/full-scorecard" title="T20I # 1879"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">T20I # 1879</span></a>]

# %%
scorecards[1]
# Out:
# <a class="ds-inline-flex ds-items-start ds-leading-none" href="/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-pakistan-final-1298179/full-scorecard" title="T20I # 1879"><span class="ds-text-tight-s ds-font-regular ds-text-typo-primary hover:ds-text-typo-primary-hover ds-block">T20I # 1879</span></a>

# %%
scorecards[1].get('href')
# Out:
# '/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-pakistan-final-1298179/full-scorecard'

# %%
scorecards[1].text
# Out:
# 'T20I # 1879'

# %%
'T20I' in scorecards[1].text
# Out:
# True

# %%
match_id = []
links = []
home = 'https://www.espncricinfo.com'
for i in scorecards:
    if 'T20I' in i.text:
        match_id.append(i.text)
        links.append(home + i.get('href'))
match_id[:5]
links[:5]
len(links)
# Out:
# 42

# %%
batting_data = []
bowling_data = []
for _ in range(len(links)+1):
    batting_head = []
    bowling_head = []
    # defining the html contents of a URL.
    for i in links:
        xhtml = url_get_contents(i).decode('utf-8')

        # Defining the HTMLTableParser object
        p = HTMLTableParser()

        # feeding the html contents in the
        # HTMLTableParser object
        p.feed(xhtml)
        batting_head.append(p.tables[0][0]) # batting column header
        bowling_head.append(p.tables[1][0]) # bowling column header

        batting_data.append(p.tables[0][1:]) # batting column data
        bowling_data.append(p.tables[1][1:]) # bowling column data

# %%
batting_data[0]
# Out:
# [['Mohammad Rizwan  †', 'b Curran', '15', '14', '24', '0', '1', '107.14'],
#  [''],
#  ['Babar Azam  (c)', 'c b Rashid', '32', '28', '58', '2', '0', '114.28'],
#  [''],
#  ['Mohammad Haris', 'c Stokes b Rashid', '8', '12', '15', '1', '0', '66.66'],
#  [''],
#  ['Shan Masood',
#   'c Livingstone b Curran',
#   '38',
#   '28',
#   '46',
#   '2',
#   '1',
#   '135.71'],
#  [''],
#  ['Iftikhar Ahmed', 'c †Buttler b Stokes', '0', '6', '8', '0', '0', '0.00'],
#  [''],
#  ['Shadab Khan', 'c Woakes b Jordan', '20', '14', '26', '2', '0', '142.85'],
#  [''],
#  ['Mohammad Nawaz',
#   'c Livingstone b Curran',
#   '5',
#   '7',
#   '11',
#   '0',
#   '0',
#   '71.42'],
#  [''],
#  ['Mohammad Wasim',
#   'c Livingstone b Jordan',
#   '4',
#   '8',
#   '12',
#   '0',
#   '0',
#   '50.00'],
#  [''],
#  ['Shaheen Shah Afridi', 'not out', '5', '3', '8', '1', '0', '166.66'],
#  ['Haris Rauf', 'not out', '1', '1', '3', '0', '0', '100.00'],
#  ['Extras', '(b 1, lb 1, nb 1, w 6)', '9', ''],
# ...

# %%
bat_df = pd.DataFrame(batting_data)
bat_df.head()
# Out:
#                                                   0   1   \
# 0  [Mohammad Rizwan  †, b Curran, 15, 14, 24, 0, ...  []
# 1  [KL Rahul, c †Buttler b Woakes, 5, 5, 8, 1, 0,...  []
# 2  [Finn Allen, lbw b Shaheen Shah Afridi, 4, 3, ...  []
# 3  [KL Rahul, c Masakadza b Sikandar Raza, 51, 35...  []
# 4  [Najmul Hossain Shanto, b Iftikhar Ahmed, 54, ...  []
#
#                                                   2   3   \
# 0  [Babar Azam  (c), c b Rashid, 32, 28, 58, 2, 0...  []
# 1  [Rohit Sharma  (c), c Curran b Jordan, 27, 28,...  []
# 2  [Devon Conway  †, run out (Shadab Khan), 21, 2...  []
# 3  [Rohit Sharma  (c), c Masakadza b Muzarabani, ...  []
# 4  [Litton Das, c Shan Masood b Shaheen Shah Afri...  []
#
#                                                   4   5   \
# 0  [Mohammad Haris, c Stokes b Rashid, 8, 12, 15,...  []
# 1  [Virat Kohli, c Rashid b Jordan, 50, 40, 75, 4...  []
# 2  [Kane Williamson  (c), b Shaheen Shah Afridi, ...  []
# ...

# %%
lk2 = 'https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2022-23-1298134/england-vs-india-2nd-semi-final-1298178/full-scorecard'
xhtml = url_get_contents(lk2).decode('utf-8')

# Defining the HTMLTableParser object
p2 = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p2.feed(xhtml)
batting_head.extend(p2.tables[0][0]) # batting column header
bowling_head.extend(p2.tables[1][0]) # bowling column header

batting_data.extend(p2.tables[0][1:]) # batting column data
bowling_data.extend(p2.tables[1][1:]) # bowling column data

# %%
print(batting_data)
# Out:
# [[['Mohammad Rizwan  †', 'b Curran', '15', '14', '24', '0', '1', '107.14'], [''], ['Babar Azam  (c)', 'c b Rashid', '32', '28', '58', '2', '0', '114.28'], [''], ['Mohammad Haris', 'c Stokes b Rashid', '8', '12', '15', '1', '0', '66.66'], [''], ['Shan Masood', 'c Livingstone b Curran', '38', '28', '46', '2', '1', '135.71'], [''], ['Iftikhar Ahmed', 'c †Buttler b Stokes', '0', '6', '8', '0', '0', '0.00'], [''], ['Shadab Khan', 'c Woakes b Jordan', '20', '14', '26', '2', '0', '142.85'], [''], ['Mohammad Nawaz', 'c Livingstone b Curran', '5', '7', '11', '0', '0', '71.42'], [''], ['Mohammad Wasim', 'c Livingstone b Jordan', '4', '8', '12', '0', '0', '50.00'], [''], ['Shaheen Shah Afridi', 'not out', '5', '3', '8', '1', '0', '166.66'], ['Haris Rauf', 'not out', '1', '1', '3', '0', '0', '100.00'], ['Extras', '(b 1, lb 1, nb 1, w 6)', '9', ''], ['TOTAL', '20 Ov  (RR: 6.85)', '137 /8', ''], ['Did not bat: Naseem Shah'], ['Fall of wickets : 1 - 29 ( Mohammad Rizwan , 4.2 ov ) , 2 - 45 ( Mohamm
# ...

# %%
batting_head
# Out:
# [['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
#  ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'],
# ...

# %%
bowling_head
# Out:
# [['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
#  ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB'],
# ...

# %%
data2= requests.get(links[0]).text
data2
# Out:
# '<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><link rel="preconnect" href="https://img1.hscicdn.com" crossorigin="anonymous"/><link rel="preconnect" href="https://dcf.espn.com" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/CiIcons/ci-icons-v2.24/fonts/icomoon.woff?gencn3" as="font" type="font/woff2" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Bold/BentonSans-Bold.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Regular/BentonSans-Regular.woff" as="font" type="font/woff" crossorigin="anonymous"/><link rel="preload" href="https://wassets.hscicdn.com/static/fonts/BentonSans/BentonSans-Medium/BentonSans-Medium.woff" as="font" type="font/woff" crossorigin="anonymous"/><script type="text/javascript">\n          /*! js-cookie v3.0.5 | MIT */\n          !function(e,t
# ...

# %%
soup = BeautifulSoup(data2,'html.parser')

# %%
# verifying tables and their classes
print("Classes of each table on this page")
for table in soup.find_all('table'):
    print(table.get('class'))
# Out:
# Classes of each table on this page
# ['ds-w-full', 'ds-table', 'ds-table-md', 'ds-table-auto', 'ci-scorecard-table']
# ['ds-w-full', 'ds-table', 'ds-table-md', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-md', 'ds-table-auto', 'ci-scorecard-table']
# ['ds-w-full', 'ds-table', 'ds-table-md', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']
# ['ds-w-full', 'ds-table', 'ds-table-sm', 'ds-table-auto']

# %%
# ds-w-full ds-table ds-table-md ds-table-auto  ci-scorecard-table
import time
tab = soup.find_all('table',class_='ds-w-full ds-table ds-table-md ds-table-auto  ci-scorecard-table')
print(tab)
# Out:
# []

# %%
# Defining the Dataframe
bat_df = pd.DataFrame(columns=['Batting','In/Out','R','B','M','Four','Six','SR'])

# Collecting data
for row in tab.find_all('tr'):
    # Find all data for each column
    cols = row.findall('td')

    if (cols !=[]):
        Batting = cols[0].span.contents[0]
        InOut = cols[1].span.contents[0]
        r = cols[2].span.contents[0]
        b = cols[3].text.strip()
        m = cols[4].text.strip()
        four = cols[5].text.strip()
        six = cols[6].text.strip()
        sr = cols[7].text.strip()

bat_df = bat_df.append({'Batting':Batting,'In/Out':InOut,'R':r,'B':b,'M':m,'Four':four,'Six':six,'SR':sr})
bat_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 5
#       2 bat_df = pd.DataFrame(columns=['Batting','In/Out','R','B','M','Four','Six','SR'])
#       4 # Collecting data
# ----> 5 for row in tab.find_all('tr'):
#       6     # Find all data for each column
#       7     cols = row.findall('td')
#       9     if (cols !=[]):
#
# File f:\Sindhura\Data Science-ETLhive\Machine Learning\Project 3-ML models\repository\venv\Lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# ...

# %%
# defining the html contents of a URL.
a= []
for i in links:
    xhtml2 = url_get_contents(i).decode('utf-8')

    # Defining the HTMLTableParser object
    p1 = HTMLTableParser()

    # feeding the html contents in the
    # HTMLTableParser object
    p1.feed(xhtml2)

    # Now finally obtaining the data of
    # the table required
    #pprint(p1.tables)
    a.append(p1.tables)
print(a)
# Out:
# [[[['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR'], ['Mohammad Rizwan  †', 'b Curran', '15', '14', '24', '0', '1', '107.14'], [''], ['Babar Azam  (c)', 'c b Rashid', '32', '28', '58', '2', '0', '114.28'], [''], ['Mohammad Haris', 'c Stokes b Rashid', '8', '12', '15', '1', '0', '66.66'], [''], ['Shan Masood', 'c Livingstone b Curran', '38', '28', '46', '2', '1', '135.71'], [''], ['Iftikhar Ahmed', 'c †Buttler b Stokes', '0', '6', '8', '0', '0', '0.00'], [''], ['Shadab Khan', 'c Woakes b Jordan', '20', '14', '26', '2', '0', '142.85'], [''], ['Mohammad Nawaz', 'c Livingstone b Curran', '5', '7', '11', '0', '0', '71.42'], [''], ['Mohammad Wasim', 'c Livingstone b Jordan', '4', '8', '12', '0', '0', '50.00'], [''], ['Shaheen Shah Afridi', 'not out', '5', '3', '8', '1', '0', '166.66'], ['Haris Rauf', 'not out', '1', '1', '3', '0', '0', '100.00'], ['Extras', '(b 1, lb 1, nb 1, w 6)', '9', ''], ['TOTAL', '20 Ov  (RR: 6.85)', '137 /8', ''], ['Did not bat: Naseem Shah'], ['Fall of wickets : 1 
# ...

# %%
a[0][0][0]
# Out:
# ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR']

# %%
a[0][0][1]
# Out:
# ['Mohammad Rizwan  †', 'b Curran', '15', '14', '24', '0', '1', '107.14']

# %%
df2 = pd.DataFrame(a[0][0][1:],columns=a[0][0][0])
df2
# Out:
#                                               BATTING                          \
# 0                                  Mohammad Rizwan  †                b Curran
# 1                                                                        None
# 2                                     Babar Azam  (c)              c b Rashid
# 3                                                                        None
# 4                                      Mohammad Haris       c Stokes b Rashid
# 5                                                                        None
# 6                                         Shan Masood  c Livingstone b Curran
# 7                                                                        None
# 8                                      Iftikhar Ahmed     c †Buttler b Stokes
# 9                                                                        None
# 10                                        Shadab Khan       c Woakes b Jordan
# ...

# %%
df2 = df2.drop(index=[1,3,5,7,9,11,13,15,18,19,20,21])
df2
# Out:
#                 BATTING                           R   B   M 4s 6s      SR
# 0    Mohammad Rizwan  †                b Curran  15  14  24  0  1  107.14
# 2       Babar Azam  (c)              c b Rashid  32  28  58  2  0  114.28
# 4        Mohammad Haris       c Stokes b Rashid   8  12  15  1  0   66.66
# 6           Shan Masood  c Livingstone b Curran  38  28  46  2  1  135.71
# 8        Iftikhar Ahmed     c †Buttler b Stokes   0   6   8  0  0    0.00
# 10          Shadab Khan       c Woakes b Jordan  20  14  26  2  0  142.85
# 12       Mohammad Nawaz  c Livingstone b Curran   5   7  11  0  0   71.42
# 14       Mohammad Wasim  c Livingstone b Jordan   4   8  12  0  0   50.00
# 16  Shaheen Shah Afridi                 not out   5   3   8  1  0  166.66
# 17           Haris Rauf                 not out   1   1   3  0  0  100.00

# %%
a[0][1][0]
# Out:
# ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB']

# %%
df3 = pd.DataFrame(a[0][1][1:],columns=a[0][1][0])
df3
# Out:
#                                              BOWLING     O     M     R     W  \
# 0                                         Ben Stokes     4     0    32     1
# 1  12.2 to  Iftikhar Ahmed ,  nibbles outside off...  None  None  None  None
# 2                                       Chris Woakes     3     0    26     0
# 3                                         Sam Curran     4     0    12     3
# 4  4.2 to  Mohammad Rizwan ,  bowled him, Rizwan'...  None  None  None  None
# 5                                        Adil Rashid     4     1    22     2
# 6  7.1 to  Mohammad Haris ,  and he strikes first...  None  None  None  None
# 7                                       Chris Jordan     4     0    27     2
# 8  17.2 to  Shadab Khan ,  another slap across th...  None  None  None  None
# 9                                   Liam Livingstone     1     0    16     0
#
#     ECON    0s    4s    6s    WD    NB
# 0   8.00     6     1     0     2     1
# 1   None  None  None  None  None  None
# ...

# %%
df3 = df3.drop(index=[1,4,6,8])
df3
# Out:
#             BOWLING  O  M   R  W   ECON  0s 4s 6s WD NB
# 0        Ben Stokes  4  0  32  1   8.00   6  1  0  2  1
# 2      Chris Woakes  3  0  26  0   8.66   7  2  1  2  0
# 3        Sam Curran  4  0  12  3   3.00  15  0  0  0  0
# 5       Adil Rashid  4  1  22  2   5.50  10  1  0  1  0
# 7      Chris Jordan  4  0  27  2   6.75   9  3  0  0  0
# 9  Liam Livingstone  1  0  16  0  16.00   1  1  1  1  0

# %%
a[1][0][0]
# Out:
# ['BATTING', '', 'R', 'B', 'M', '4s', '6s', 'SR']

# %%
a[1][0][1]
# Out:
# ['KL Rahul', 'c †Buttler b Woakes', '5', '5', '8', '1', '0', '100.00']

# %%
a[1][1][0]
# Out:
# ['BOWLING', 'O', 'M', 'R', 'W', 'ECON', '0s', '4s', '6s', 'WD', 'NB']

# %%
a[1][1][1]
# Out:
# ['Ben Stokes', '2', '0', '18', '0', '9.00', '5', '2', '1', '0', '0']
